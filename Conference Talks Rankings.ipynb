# %% [markdown]
# <div style="background-color: rgb(51, 51, 51)">
#     <img src='logos/pycon8.png' width='50%' />
# </div>

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# <a name="absolute_rank"></a>
# # Community Voting Results
#
# ### Absolute Ranking

# %%
rankings = pd.read_csv('./ranking.txt', sep='~', skiprows=1, header=0)
rankings.drop('TID', axis=1, inplace=True)
rankings.drop('Idx', axis=1, inplace=True)

union_jack = '\U0001F1EC\U0001F1E7'
tricolore = '\U0001F1EE\U0001F1F9'

rankings.Gender = rankings.Gender.apply(lambda g: '+'.join('\U0001f469\u200d\U0001f4bb' if l=='female' else '\U0001f468\u200d\U0001f4bb' 
                                         for l in g.split(',')))
rankings.Lang = rankings.Lang.apply(lambda l: union_jack if l=='en' else tricolore)
pd.set_option('display.max_rows', rankings.index.size)
pd.set_option('display.max_colwidth', 200)
rankings
# Out:
#          Type  Duration  \
# 0        Talk        45
# 1        Talk        90
# 2        Talk        45
# 3        Talk        45
# 4        Talk        45
# 5        Talk        45
# 6        Talk        45
# 7        Talk        60
# 8        Talk        60
# 9    Training       240
# 10       Talk        60
# 11       Talk        45
# 12       Talk        60
# 13       Talk        45
# 14       Talk        30
# 15       Talk        45
# 16       Talk        60
# 17       Talk        45
# 18       Talk        45
# 19       Talk        45
# 20       Talk        60
# 21       Talk        45
# 22       Talk        60
# 23       Talk        45
# 24       Talk        45
# 25       Talk        45
# 26       Talk        45
# 27       Talk        45
# 28       Talk        30
# 29       Talk        60
# 30       Talk        45
# 31       Talk        60
# 32       Talk        45
# 33   Training       240
# 34       Talk        60
# 35       Talk        45
# 36       Talk        60
# 37       Talk        45
# 38       Talk        45
# 39       Talk        60
# 40       Talk        30
# 41       Talk        45
# 42       Talk        45
# 43       Talk        45
# 44   Training       240
# 45       Talk        60
# 46       Talk        60
# 47       Talk        45
# 48       Talk        45
# 49       Talk        45
# 50       Talk        30
# 51       Talk        60
# 52       Talk        60
# 53       Talk        45
# 54       Talk        30
# 55       Talk        45
# 56       Talk        30
# 57       Talk        30
# 58       Talk        60
# 59       Talk        45
# 60       Talk        45
# 61       Talk        60
# 62       Talk        45
# 63       Talk        30
# 64       Talk        45
# 65       Talk        45
# 66       Talk        30
# 67       Talk        60
# 68       Talk        60
# 69       Talk        30
# 70       Talk        45
# 71       Talk        30
# 72       Talk        60
# 73       Talk        60
# 74       Talk        60
# 75       Talk        45
# 76       Talk        45
# 77       Talk        45
# 78   Training       240
# 79       Talk        30
# 80       Talk        45
# 81       Talk        45
# 82       Talk        45
# 83       Talk        45
# 84       Talk        60
# 85       Talk        30
# 86       Talk        45
# 87       Talk        45
# 88       Talk        45
# 89       Talk        45
# 90       Talk        45
# 91       Talk        30
# 92       Talk        30
# 93       Talk        60
# 94       Talk        45
# 95       Talk        45
# 96       Talk        30
# 97       Talk        45
# 98       Talk        45
# 99       Talk        30
# 100      Talk        30
# 101      Talk        60
# 102      Talk        60
# 103      Talk        45
# 104      Talk        45
# 105  Training       240
# 106      Talk        45
# 107  Training       240
# 108      Talk        45
# 109      Talk        30
# 110      Talk        60
# 111      Talk        30
# 112      Talk        30
# 113      Talk        30
# 114      Talk        30
# 115      Talk        60
# 116      Talk        30
# 117  Training       240
# 118      Talk        45
# 119      Talk        60
# 120      Talk        45
# 121      Talk        45
# 122      Talk        45
# 123      Talk        30
# 124      Talk        30
# 125      Talk        45
# 126      Talk        45
# 127      Talk        60
# 128      Talk        45
# 129      Talk        45
# 130      Talk        45
# 131      Talk        45
# 132      Talk        45
# 133      Talk        45
# 134      Talk        45
# 135      Talk        30
# 136      Talk        45
# 137      Talk        45
# 138      Talk        45
# 139      Talk        45
# 140      Talk        30
# 141      Talk        45
# 142      Talk        30
# 143      Talk        45
# 144      Talk        45
# 145      Talk        60
# 146      Talk        45
# 147      Talk        45
# 148      Talk        45
# 149      Talk        30
# 150      Talk        30
# 151      Talk        30
# 152      Talk        45
# 153      Talk        60
# 154  Training       240
# 155      Talk        45
# 156      Talk        45
# 157  Training       240
# 158      Talk        30
# 159      Talk        30
# 160      Talk        30
# 161      Talk        30
# 162      Talk        45
# 163      Talk        30
# 164      Talk        45
# 165      Talk        30
# 166      Talk        30
# 167      Talk        60
# 168      Talk        60
# 169      Talk        45
# 170      Talk        45
# 171      Talk        45
# 172      Talk        45
# 173      Talk        30
# 174      Talk        30
# 175      Talk        30
# 176      Talk        45
# 177      Talk        30
# 178      Talk        45
# 179      Talk        45
# 180      Talk        30
#
#                                                                                                     Title  \
# 0                                                      AI, Machine Learning e Deep Learning: cosa cambia?
# 1                                                                L’Italia, python e la chimera dell’Agile
# 2                                                 Facial Analysis Techniques for Pythonista (and beyond!)
# 3                                                                                       Performant Python
# 4                                                                                 Demystifying Decorators
# 5                                                                     Solving the Rubiks Cube with Python
# 6                                                            Building Serverless applications with Python
# 7                                                                                 Deep Learning made easy
# 8                                                        The unconventional Introduction to Deep Learning
# 9                                                                            Deep Learning, the Keras way
# 10                                                 A Gentle Introduction to Neural Networks (with Python)
# 11                                                              Introduction to Data-Analysis with Pandas
# 12              Machine Learning con Python: previsione in real-time della richiesta di energia elettrica
# 13                             Create a serverless infrastructure for data collection with Python and AWS
# 14                                                            Tales from the Crypt: A Cryptography Primer
# 15                            ByteCode al supporto dei test per protocolli ed enforcing di best practices
# 16                                 Solving the web most popular code shortening competition with Python 3
# 17                                               Affrontare le sfide del cambiamento climatico con Python
# 18                                                                       Time Series Analysis with Pandas
# 19                                                                  Unreal Engine 4 e Python: Ora si Puo'
# 20                                     Machine Learning con Python: algoritmi NILM e real-time processing
# 21                                                                              OpenCV for face detection
# 22      Digital Analytics Data Aggregation: un case study dal mondo reale utilizzando SQL, NoSQL e Pandas
# 23                        Is it too late to learn how to program and how being a developer change my life
# 24                                                                               Perché Python fa schifo!
# 25                                  Indicizzare e ricercare tonnellate di dati con ElasticSearch e Django
# 26                                                                    Django Rest Framework - Tips&Tricks
# 27                                                                 How to turn Wikipedia into a Quiz Game
# 28                             Out of Sight, Out of Mind: Survival tricks and tools for remote developers
# 29                         Where are you going? An overview on machine learning models for human mobility
# 30                                                                                Python on $5 IoT Device
# 31                       Tensor decomposition with Python: Learning structures from multidimensional data
# 32                                                  An Introduction to Pandas for Data Analysis in Python
# 33                                                                       Quattro ore di Silenzio Assoluto
# 34                                                                                     PyPy Status Update
# 35                                                                               Crash test of Django ORM
# 36                                                                  Understanding Serverless Architecture
# 37                                                             Getting started with requests HTTP library
# 38                                                      Basic principles of scientific data visualization
# 39                                                                  Serverless computing con Python e AWS
# 40                                                          Behavioral Driven Development: Tame the Beast
# 41                                                                         Explore the brain with Nilearn
# 42                                  An Introduction to Feature Selection in Machine Learning using Python
# 43   Word Embedding: come codificare il linguaggio naturale per algoritmi di previsione e classificazione
# 44                                                         Intro to Natural Language Processing in Python
# 45                                           The Journey Of aeneas: A Python Adventure In Text and Speech
# 46                                                                                       Python in Africa
# 47                                                                  Python e swift: linguaggi a confronto
# 48                                                    Jupyter: if you don't use it yet you're doing wrong
# 49                                        Deploy automatizzato di un progetto Python 3/Django con Ansible
# 50                                            From Idea to Presentation: How to Prepare a Conference Talk
# 51                                                                                     E.T. chiama Python
# 52                                                               Serverless computing with Python and AWS
# 53                                                 Why I still develop synchronous web in the asyncIO era
# 54                                                               Be(come) a Mentor! Help Others Succeed!
# 55                                                                 Test Driven Deployment with Ansible 2.
# 56                             No Coding Skills Required: How to Contribute to Open Source in Other Ways
# 57                                       Django among modern web frameworks – was Angular2 a good choice?
# 58                                                                             42 PyCharm Tips and Tricks
# 59                                                           An Introduction to web scraping using Python
# 60                                              Perché sviluppo ancora web sincrono nell'era dell'asyncIO
# 61                                                        Realizzare stampe HTML e PDF usando solo Python
# 62                                                                 Chat Bot in Telegram (e slack e altri)
# 63                                                                         Django and the testing pyramid
# 64                                                                             Growing a Python community
# 65                                                                         Sparking Pandas: an experiment
# 66                                                        Data loss prevention in modern web applications
# 67                                                                      Don't try to look smart. Be smart
# 68                                                      Amazon Web Services for dummies - tips and tricks
# 69                                                                             Compassionate Code Reviews
# 70                                                         OpneSSH SFTP service con Python: pysftpserver.
# 71                 Rants and Ruminations From A Job Applicant After 💯 CS Job Interviews in Silicon Valley
# 72                                            Amazon Web Services per i principianti - consigli e trucchi
# 73                                                             Creare videogiochi per smartphone con Kivy
# 74                                                                                           Rusty Python
# 75             Space weather monitoring for a simulation of a Martian settlement based on Virtual Reality
# 76                                                                        Full Text Search con PostgreSQL
# 77                                                      Disaster recovery: una serie di sfortunati eventi
# 78                                                                 Scrivere Chat Bot per Telegram e Slack
# 79                                                               The Hidden Power Dynamics of Open Source
# 80                                                              Catching Neutrinos with Python and KM3NeT
# 81                                                                       Svilluppare con python sull'iPad
# 82                                      Il Viaggio di aeneas: Un'Avventura Con Python Tra Testo e Parlato
# 83                                                                            Just one Shade of OpenStack
# 84                                                              Python e PostgreSQL, un connubio perfetto
# 85                          Applying the unix philosophy to django projects: a report from the real world
# 86                                      Taiga e l’agile project management: join the Oompa Loompas’ Army!
# 87                                              Plugin Based Chat Bots in Telegram (and Slack and others)
# 88                                                                           Da applicativi Desktop a Web
# 89                                                  Open edX, soluzione per l'e-learning basata su Django
# 90                                             Automated deploy of a Python 3/Django project with Ansible
# 91                                                                 Type uWSGI; press enter; what happens?
# 92                                                            Planet friendly web development with Django
# 93                                                                      weppy: il framework web per umani
# 94                                              Word Embeddings for Natural Language Processing in Python
# 95                                         Scientific Hooliganism: lessons from the first hack in history
# 96          Threading Yarn, Writing Code: What Traditional Arts and Crafts Can Teach Us About Programming
# 97                                                    Attack of Pythons : Gotchas and Landmines in Python
# 98                                             Presenting pysftpserver: OpenSSH SFTP service with Python.
# 99                                                                            Navigating unconscious bias
# 100                                                     Loop better: a deeper look at iteration in Python
# 101                                                       Validazione e decodifica di file XML con Python
# 102                                             Dai dati alla visualizzazione: la mia prima data pipeline
# 103                                                                      Django nella giungla Javascript
# 104                                                            Ricerca full text in Django con PostgreSQL
# 105                                        Supervised learning in high dimensional data: from zero to ℵ-0
# 106                                          Ansible roles, private git repos and the Ansible Galaxy tool
# 107                                                Writing Plugin Based Chat Bots in Telegram (and Slack)
# 108                                                                       How to use pandas the wrong way
# 109                                                                         Comprehensible Comprehensions
# 110                                                                                     E.T. phone Python
# 111                                                          Leading an open source project as a startup.
# 112                                                            The hard long journey of submitting a form
# 113                                                          Security Starts With You: Social Engineering
# 114                                                                                   How Not To Password
# 115                                                                 Infrastructure as Code with Terraform
# 116                            The mullet architecture - Elasticsearch in the front, Postgres in the back
# 117                                                                       Costruiamo l’Internet dei Robot
# 118                                                              Rules of thumb to test the documentation
# 119                                                              Infrastruttura come codice con Terraform
# 120                                           Geospatial three amigos: Python, Leaflet, and ElasticSearch
# 121                                                 ZimboPy: Empowering Zimbabwean Girls As Change Makers
# 122                                                    Continuous Delivery for Iot with Python and Iottly
# 123                                                                   Python, Locales and Writing Systems
# 124                                                                   Django Admin - The Swiss Army Knife
# 125                                   Keeping up with the pace of a fast growing community without dying
# 126                                                                     Analisi dati e grafici in Genropy
# 127                                                             Cross-platform game development with Kivy
# 128                                                                           Combating Impostor Syndrome
# 129                      MIT MicroMasters: come sviluppare una web application basata su servizi esterni.
# 130                                                                      PostgreSQL su NFS: miti e verità
# 131        Misura: Un sistema per il controllo strumentale, l'acquisizione dati ed il calcolo scientifico
# 132                                                                       The Wild West of Data Wrangling
# 133                           Ansible: sviluppo e utilizzo di roles seguendo il modello di Ansible Galaxy
# 134                                                                                Come usare male pandas
# 135                              Serverlessness - augmenting your Django apps with Functions-as-a-Service
# 136                                                               Monitoring Beach Morphology with Python
# 137                                              Artistic Python: Mixing Python Programming with Fashion
# 138                                                                         Python + Windows, like a boss
# 139                                        Pilotare un braccio robotico dal cloud con GenroPy e Raspberry
# 140                                                               Qualities of great reusable Django apps
# 141                             Differential network analysis and graph classification: a glocal approach
# 142                                                                          Never Accept the First Offer
# 143                                           Roboto Framework for Test Code Coverage for cloud services.
# 144                 RFLab - Controllo remoto strumentazione di un laboratorio nel settore delle microonde
# 145                                                                   weppy: the web framework for humans
# 146                                                        iCond: GenroPy per amministratori di condomini
# 147                                                                         Sviluppo lato client con Odoo
# 148                                                         Fuzzy is the new sexy: a tour of scikit-fuzzy
# 149                                                                        Scaling Django with Kubernetes
# 150                                                                                  Mastering Your Tools
# 151                                          Beginning with django? Why you need to continue with django
# 152                                                                                           Awesome CLI
# 153                Creazione ed evoluzione di un framework per interfacce grafiche Multi-Touch con OpenGL
# 154                                          Creiamo un'applicazione per la gestione di ticket in Genropy
# 155                                                                      Form e Campi dinamici in Genropy
# 156                               Real-time Trajectory Optimization through contacts, a simple test case.
# 157                                              Quando il saggio indica il cielo, pandas guarda l'indice
# 158            Migrating from JavaEE to Django: the OSIS case of embracing cultural and technical changes
# 159                                                                          Why the Internet Loves Cats
# 160                                                                 James and the Giant Forensics Toolkit
# 161                                                                                 Time Tracking is Hard
# 162                                                                Taking care of PostgreSQL with Ansible
# 163                                                                            The Monster on the Project
# 164                   ENVIFATE: plugin per QGIS per la valutazione del rischio di inquinamento ambientale
# 165                                                             Integrating the Bokeh library with Django
# 166                                                    Preventing issues on Django with linters and tools
# 167                                                 Genropy: 10 anni di sviluppo di un framework italiano
# 168                                           Django ORM in server TCP con backend multischema PostgreSQL
# 169        LiFT - Un tagger di features per l’analisi multidimensionale di testi ottimizzato per PySpark
# 170                                                          Terrain Generation in Python with Processing
# 171       Genropy - Caso d'uso: gestione di una infrastruttura telefonica VoIP di medie/grandi dimensioni
# 172                                                                                    Un anno di Genropy
# 173                                                                                     Dial M For Mentor
# 174                                                        Deploying your django application using puppet
# 175                                Addons: I can solve 90% of your problems. The other 90% are up to you.
# 176                                                                  ADENINE: A Data ExploratioN pIpeliNE
# 177                                                 People Are Coming To My Beginning Workshop, What Now?
# 178                                                     Wargame web app - Odoo come framework di sviluppo
# 179                                                                    Usare Erpy da applicazioni esterne
# 180                                                                                  Using SASS in Django
#
#            Track         Level Lang                         Speakers   Gender
# 0         PyData      Beginner   🇮🇹                  Antonio Spadaro      👨‍💻
# 1    PyCommunity  Intermediate   🇮🇹                Gabriele Giaccari      👨‍💻
# 2         PyData  Intermediate   🇬🇧                   Alex Casalboni      👨‍💻
# 3         PyLang      Beginner   🇬🇧                   Burkhard Kloss      👨‍💻
# 4         PyLang      Beginner   🇬🇧                       Akul Mehra      👨‍💻
# 5         PyData  Intermediate   🇬🇧                  Daan van Berkel      👨‍💻
# 6          PyWeb      Advanced   🇬🇧                Andrii Soldatenko      👨‍💻
# 7         PyData      Beginner   🇬🇧                  Jalem Raj Rohit      👨‍💻
# 8         PyData      Beginner   🇬🇧                   Valerio Maggio      👨‍💻
# 9         PyData  Intermediate   🇬🇧                   Valerio Maggio      👨‍💻
# 10        PyData      Beginner   🇬🇧                     Tariq Rashid      👨‍💻
# 11        PyData      Beginner   🇬🇧                Alexander Hendorf      👨‍💻
# 12        PyData      Beginner   🇮🇹                    Felice Tuosto      👨‍💻
# 13         PyWeb  Intermediate   🇮🇹                   David Santucci      👨‍💻
# 14        PyLang      Beginner   🇬🇧                   Adam Englander      👨‍💻
# 15        PyLang  Intermediate   🇮🇹                Alessandro Molina      👨‍💻
# 16        PyLang  Intermediate   🇬🇧                 Alessandro Amici      👨‍💻
# 17        PyData      Beginner   🇮🇹                 Alessandro Amici      👨‍💻
# 18        PyData  Intermediate   🇬🇧                Alexander Hendorf      👨‍💻
# 19        PyLang      Beginner   🇮🇹                 Roberto De Ioris      👨‍💻
# 20        PyData      Beginner   🇮🇹                    Felice Tuosto      👨‍💻
# 21        PyData      Beginner   🇬🇧                        Ken Alger      👨‍💻
# 22    PyDatabase      Advanced   🇮🇹            Alessandro Pelliciari      👨‍💻
# 23   PyCommunity      Beginner   🇬🇧                      Alicia Carr      👩‍💻
# 24   PyCommunity      Beginner   🇮🇹                  Antonio Spadaro      👨‍💻
# 25         PyWeb  Intermediate   🇮🇹                 Ernesto Arbitrio      👨‍💻
# 26         PyWeb      Beginner   🇮🇹                   Luca Zacchetti      👨‍💻
# 27        PyData      Beginner   🇬🇧   Andrea Cappelli,Roberto Turrin  👨‍💻+👨‍💻
# 28         PyWeb      Beginner   🇬🇧                Alessio Bragadini      👨‍💻
# 29        PyData      Beginner   🇮🇹                 Gianni Barlacchi      👨‍💻
# 30        PyLang      Beginner   🇬🇧                        Ken Alger      👨‍💻
# 31        PyData  Intermediate   🇮🇹                   André Panisson      👨‍💻
# 32        PyData      Beginner   🇬🇧                Ayush Kumar Singh      👨‍💻
# 33        PyLang      Advanced   🇬🇧                      Carlo Miron      👨‍💻
# 34        PyLang  Intermediate   🇬🇧                     Antonio Cuni      👨‍💻
# 35         PyWeb  Intermediate   🇬🇧                Andrii Soldatenko      👨‍💻
# 36         PyWeb      Beginner   🇬🇧                  Jalem Raj Rohit      👨‍💻
# 37         PyWeb      Beginner   🇮🇹                    Andrea Grandi      👨‍💻
# 38        PyData      Beginner   🇬🇧                  Giuseppe Jurman      👨‍💻
# 39         PyWeb  Intermediate   🇮🇹                  Federico Caboni      👨‍💻
# 40        PyLang      Beginner   🇬🇧                   Adam Englander      👨‍💻
# 41        PyData  Intermediate   🇬🇧                    Darya Chyzhyk      👩‍💻
# 42        PyData      Beginner   🇬🇧                    Rahul Baboota      👨‍💻
# 43        PyData      Beginner   🇮🇹       Felice Tuosto,Andrea Ianni  👨‍💻+👨‍💻
# 44        PyData      Beginner   🇬🇧                  Marco Bonzanini      👨‍💻
# 45        PyData  Intermediate   🇬🇧                 Alberto Pettarin      👨‍💻
# 46   PyCommunity      Beginner   🇬🇧                   Anna Makarudze      👩‍💻
# 47        PyLang  Intermediate   🇮🇹                  Lelio Campanile      👨‍💻
# 48        PyData      Beginner   🇬🇧                  Christian Barra      👨‍💻
# 49         PyWeb  Intermediate   🇮🇹                 Marco Santamaria      👨‍💻
# 50   PyCommunity      Beginner   🇬🇧                    Anna Ossowski      👩‍💻
# 51   PyCommunity  Intermediate   🇮🇹                     Davide Corio      👨‍💻
# 52         PyWeb  Intermediate   🇬🇧                  Federico Caboni      👨‍💻
# 53         PyWeb  Intermediate   🇬🇧               Giovanni Barillari      👨‍💻
# 54   PyCommunity      Beginner   🇬🇧                    Anna Ossowski      👩‍💻
# 55        PyLang  Intermediate   🇬🇧                    Roberto Polli      👨‍💻
# 56   PyCommunity      Beginner   🇬🇧                    Anna Ossowski      👩‍💻
# 57         PyWeb  Intermediate   🇬🇧                 Andrzej Krawczyk      👨‍💻
# 58        PyLang      Beginner   🇬🇧                  Dmitry Trofimov      👨‍💻
# 59         PyWeb      Beginner   🇬🇧                     Manoj Pandey      👨‍💻
# 60         PyWeb  Intermediate   🇮🇹               Giovanni Barillari      👨‍💻
# 61    PyBusiness      Beginner   🇮🇹                  Saverio Porcari      👨‍💻
# 62        PyLang      Beginner   🇮🇹  Lorenzo Buonanno,Tommaso Sartor  👨‍💻+👨‍💻
# 63         PyWeb  Intermediate   🇬🇧                    Aaron Bassett      👨‍💻
# 64   PyCommunity      Beginner   🇬🇧                    Anton Caceres      👨‍💻
# 65        PyData  Intermediate   🇬🇧                  Francesco Bruni      👨‍💻
# 66         PyWeb      Beginner   🇬🇧                  Xavier Dutreilh      👨‍💻
# 67   PyCommunity      Beginner   🇬🇧                   Flavio Percoco      👨‍💻
# 68         PyWeb      Beginner   🇬🇧               Justyna Janczyszyn      👩‍💻
# 69   PyCommunity      Beginner   🇬🇧                     April Wensel      👩‍💻
# 70         PyWeb  Intermediate   🇮🇹                  Filippo Morelli      👨‍💻
# 71   PyCommunity      Beginner   🇬🇧                        Susan Tan      👩‍💻
# 72         PyWeb      Beginner   🇮🇹               Justyna Janczyszyn      👩‍💻
# 73        PyLang  Intermediate   🇮🇹                   Rigel Di Scala      👨‍💻
# 74        PyLang  Intermediate   🇮🇹                   Matteo Bertini      👨‍💻
# 75        PyData      Beginner   🇬🇧                   Giovanni Bruno      👨‍💻
# 76    PyDatabase      Beginner   🇮🇹                Giuseppe Broccolo      👨‍💻
# 77    PyDatabase      Beginner   🇮🇹                  Giulio Calacoci      👨‍💻
# 78        PyLang      Beginner   🇮🇹  Lorenzo Buonanno,Tommaso Sartor  👨‍💻+👨‍💻
# 79   PyCommunity      Beginner   🇬🇧                    Anna Ossowski      👩‍💻
# 80        PyData      Beginner   🇬🇧                        Tamás Gál      👨‍💻
# 81        PyLang      Beginner   🇮🇹                  Lelio Campanile      👨‍💻
# 82        PyData      Beginner   🇮🇹                 Alberto Pettarin      👨‍💻
# 83        PyLang      Beginner   🇬🇧                    Roberto Polli      👨‍💻
# 84    PyDatabase      Beginner   🇮🇹                 Marco Nenciarini      👨‍💻
# 85   PyCommunity      Beginner   🇬🇧                 Federico Capoano      👨‍💻
# 86   PyCommunity  Intermediate   🇮🇹                Gabriele Giaccari      👨‍💻
# 87        PyLang      Beginner   🇬🇧  Lorenzo Buonanno,Tommaso Sartor  👨‍💻+👨‍💻
# 88    PyBusiness      Beginner   🇮🇹                      Luigi Renna      👨‍💻
# 89         PyWeb      Beginner   🇮🇹                     Davide Corio      👨‍💻
# 90         PyWeb  Intermediate   🇬🇧                 Marco Santamaria      👨‍💻
# 91         PyWeb      Advanced   🇬🇧                     Philip James      👨‍💻
# 92         PyWeb  Intermediate   🇬🇧                      Chris Adams      👨‍💻
# 93         PyWeb      Beginner   🇮🇹               Giovanni Barillari      👨‍💻
# 94        PyData      Beginner   🇬🇧                  Marco Bonzanini      👨‍💻
# 95   PyCommunity      Beginner   🇬🇧                       Lilly Ryan      👩‍💻
# 96   PyCommunity      Beginner   🇬🇧                    Anna Ossowski      👩‍💻
# 97        PyLang      Beginner   🇬🇧                     Manoj Pandey      👨‍💻
# 98         PyWeb  Intermediate   🇬🇧                  Filippo Morelli      👨‍💻
# 99   PyCommunity      Beginner   🇬🇧                   Anna Schneider      👩‍💻
# 100       PyLang  Intermediate   🇬🇧                      Trey Hunner      👨‍💻
# 101       PyData  Intermediate   🇮🇹                   Davide Brunato      👨‍💻
# 102       PyData      Beginner   🇮🇹           Riccardo Magliocchetti      👨‍💻
# 103        PyWeb      Beginner   🇮🇹            Patrick Guido Arminio      👨‍💻
# 104   PyDatabase  Intermediate   🇮🇹                 Paolo Melchiorre      👨‍💻
# 105       PyData      Beginner   🇬🇧                  Matteo Barbieri      👨‍💻
# 106       PyLang  Intermediate   🇬🇧                 serena lorenzini      👩‍💻
# 107       PyLang      Beginner   🇬🇧  Lorenzo Buonanno,Tommaso Sartor  👨‍💻+👨‍💻
# 108       PyData  Intermediate   🇬🇧                 Pietro Battiston      👨‍💻
# 109       PyLang      Beginner   🇬🇧                      Trey Hunner      👨‍💻
# 110  PyCommunity  Intermediate   🇬🇧                     Davide Corio      👨‍💻
# 111  PyCommunity      Beginner   🇬🇧                  Nicolas Garnier      👨‍💻
# 112        PyWeb  Intermediate   🇬🇧        Filipe de Alencar Ximenes      👨‍💻
# 113  PyCommunity      Beginner   🇬🇧                 Tiberius Hefflin      👨‍💻
# 114  PyCommunity      Beginner   🇬🇧                 Tiberius Hefflin      👨‍💻
# 115        PyWeb      Beginner   🇬🇧               Justyna Janczyszyn      👩‍💻
# 116        PyWeb  Intermediate   🇬🇧                       Honza Král      👨‍💻
# 117       PyLang      Beginner   🇬🇧           Ludovico Orlando Russo      👨‍💻
# 118       PyLang  Intermediate   🇮🇹                      Marco Buttu      👨‍💻
# 119        PyWeb      Beginner   🇮🇹               Justyna Janczyszyn      👩‍💻
# 120        PyWeb      Beginner   🇬🇧                  Roberto Rosario      👨‍💻
# 121  PyCommunity      Beginner   🇬🇧                 Marlene Mhangami      👩‍💻
# 122       PyLang  Intermediate   🇬🇧                    Stefano Terna      👨‍💻
# 123       PyLang  Intermediate   🇬🇧                      Rae Knowler      👩‍💻
# 124        PyWeb  Intermediate   🇬🇧                    Prakash Kumar      👨‍💻
# 125  PyCommunity      Beginner   🇬🇧                   Flavio Percoco      👨‍💻
# 126   PyBusiness      Beginner   🇮🇹                Francesco Porcari      👨‍💻
# 127       PyLang  Intermediate   🇮🇹                   Rigel Di Scala      👨‍💻
# 128  PyCommunity      Beginner   🇬🇧                        Ken Alger      👨‍💻
# 129        PyWeb      Beginner   🇮🇹                Giovanni Di Milia      👨‍💻
# 130   PyDatabase  Intermediate   🇮🇹                Jonathan Battiato      👨‍💻
# 131       PyData      Beginner   🇮🇹                Daniele Paganelli      👨‍💻
# 132       PyData  Intermediate   🇬🇧                      Sarah Guido      👩‍💻
# 133       PyLang  Intermediate   🇮🇹                 serena lorenzini      👩‍💻
# 134       PyData  Intermediate   🇮🇹                 Pietro Battiston      👨‍💻
# 135        PyWeb  Intermediate   🇬🇧                        Tom Dyson      👨‍💻
# 136       PyData      Beginner   🇮🇹                     Luca Liberti      👨‍💻
# 137       PyLang      Beginner   🇬🇧                     Ria Baldevia      👩‍💻
# 138       PyLang  Intermediate   🇬🇧                   Nicola Iarocci      👨‍💻
# 139       PyLang      Beginner   🇮🇹                 Michele Bertoldi      👨‍💻
# 140        PyWeb  Intermediate   🇬🇧   Flávio Juvenal da Silva Junior      👨‍💻
# 141       PyData  Intermediate   🇬🇧                  Giuseppe Jurman      👨‍💻
# 142  PyCommunity      Beginner   🇬🇧                 Tiberius Hefflin      👨‍💻
# 143       PyLang      Beginner   🇬🇧                   khushbu parakh      👩‍💻
# 144       PyData  Intermediate   🇮🇹                      Andrea Saba      👨‍💻
# 145        PyWeb      Beginner   🇬🇧               Giovanni Barillari      👨‍💻
# 146   PyBusiness      Beginner   🇮🇹                 Andrea Busanelli      👨‍💻
# 147   PyBusiness      Advanced   🇮🇹                     Davide Corio      👨‍💻
# 148       PyData      Beginner   🇮🇹                    Niccolo Raspa      👨‍💻
# 149        PyWeb  Intermediate   🇬🇧                    Saket Bhushan      👨‍💻
# 150  PyCommunity      Beginner   🇬🇧             Miguel Branco Palhas      👨‍💻
# 151        PyWeb      Beginner   🇬🇧                 Opetunde Adepoju      👩‍💻
# 152       PyLang      Beginner   🇬🇧                        Mark Fink      👨‍💻
# 153       PyLang      Advanced   🇮🇹                  Tiziano Carotti      👨‍💻
# 154   PyBusiness      Beginner   🇬🇧                Francesco Porcari      👨‍💻
# 155   PyBusiness      Beginner   🇮🇹                Francesco Porcari      👨‍💻
# 156       PyData  Intermediate   🇮🇹                   Tommaso Sartor      👨‍💻
# 157       PyData      Beginner   🇮🇹                 Pietro Battiston      👨‍💻
# 158        PyWeb      Beginner   🇬🇧              Hildeberto Mendonca      👨‍💻
# 159  PyCommunity      Beginner   🇬🇧                 Tiberius Hefflin      👨‍💻
# 160       PyLang      Beginner   🇬🇧                 Tiberius Hefflin      👨‍💻
# 161  PyCommunity  Intermediate   🇬🇧                         Sam Deng      👨‍💻
# 162   PyDatabase      Beginner   🇬🇧                     Rubens Souza      👨‍💻
# 163  PyCommunity      Beginner   🇬🇧                 Tiberius Hefflin      👨‍💻
# 164       PyLang      Beginner   🇮🇹                   Francesco Geri      👨‍💻
# 165        PyWeb      Beginner   🇬🇧                        Ken Alger      👨‍💻
# 166        PyWeb      Beginner   🇬🇧   Flávio Juvenal da Silva Junior      👨‍💻
# 167   PyBusiness      Beginner   🇮🇹                 Giovanni Porcari      👨‍💻
# 168        PyWeb  Intermediate   🇮🇹                     Luca Ferroni      👨‍💻
# 169       PyData      Beginner   🇮🇹                   Michele Gabusi      👨‍💻
# 170       PyLang  Intermediate   🇮🇹                    Paolo Improta      👨‍💻
# 171   PyBusiness      Beginner   🇮🇹                    Mauro Zanardi      👨‍💻
# 172   PyBusiness      Beginner   🇮🇹         Muhammad Hassan Khurshid      👨‍💻
# 173  PyCommunity      Beginner   🇬🇧                  Mariatta Wijaya      👩‍💻
# 174        PyWeb      Beginner   🇬🇧                  Krzysztof Żuraw      👨‍💻
# 175        PyWeb  Intermediate   🇬🇧                    Stefan Foulis      👨‍💻
# 176       PyData      Beginner   🇬🇧                  Samuele Fiorini      👨‍💻
# 177  PyCommunity      Beginner   🇬🇧                   Nicholle James      👩‍💻
# 178   PyBusiness  Intermediate   🇮🇹               Nicola Malcontenti      👨‍💻
# 179   PyBusiness      Beginner   🇮🇹                 Giovanni Porcari      👨‍💻
# 180        PyWeb      Beginner   🇬🇧                       Jacob Rief      👨‍💻

# %%
trainings = rankings[rankings['Type'].values == 'Training']
talks = rankings[rankings['Type'].values == 'Talk']

# %% [markdown]
# # Stats

# %% [markdown]
# ## Speakers Stats

# %%
from collections import defaultdict
speakers = defaultdict(set)

# %%
for i, speaker in enumerate(rankings.Speakers.values):
    for j, name in enumerate(speaker.split(',')):
        gender = rankings.Gender[i].split('+')[j]
        speakers[gender].add(name)

# %%
count_speakers = sum(len(s) for s in speakers.values())
print(count_speakers)
# Out:
# 130

# %%
for k in speakers:
    print('{} --> {}'.format(k, len(speakers[k])))
# Out:
# 👨‍💻 --> 112
# 👩‍💻 --> 18

# %% [markdown]
# ## Talks Stats

# %%
print('Talks --> {}'.format(talks.index.size))
print('Trainings --> {}'.format(trainings.index.size))
# Out:
# Talks --> 172
# Trainings --> 9

# %% [markdown]
# ### Lang

# %%
rankings.Lang.value_counts()
# Out:
# 🇬🇧    112
# 🇮🇹     69
# Name: Lang, dtype: int64

# %% [markdown]
# ### Level

# %%
rankings.Level.value_counts()
# Out:
# Beginner        114
# Intermediate     61
# Advanced          6
# Name: Level, dtype: int64

# %% [markdown]
# <a name="trainings"></a>
# # Trainings Ranking

# %%
trainings
# Out:
#          Type  Duration  \
# 9    Training       240
# 33   Training       240
# 44   Training       240
# 78   Training       240
# 105  Training       240
# 107  Training       240
# 117  Training       240
# 154  Training       240
# 157  Training       240
#
#                                                               Title  \
# 9                                      Deep Learning, the Keras way
# 33                                 Quattro ore di Silenzio Assoluto
# 44                   Intro to Natural Language Processing in Python
# 78                           Scrivere Chat Bot per Telegram e Slack
# 105  Supervised learning in high dimensional data: from zero to ℵ-0
# 107          Writing Plugin Based Chat Bots in Telegram (and Slack)
# 117                                 Costruiamo l’Internet dei Robot
# 154    Creiamo un'applicazione per la gestione di ticket in Genropy
# 157        Quando il saggio indica il cielo, pandas guarda l'indice
#
#           Track         Level Lang                         Speakers   Gender
# 9        PyData  Intermediate   🇬🇧                   Valerio Maggio      👨‍💻
# 33       PyLang      Advanced   🇬🇧                      Carlo Miron      👨‍💻
# 44       PyData      Beginner   🇬🇧                  Marco Bonzanini      👨‍💻
# 78       PyLang      Beginner   🇮🇹  Lorenzo Buonanno,Tommaso Sartor  👨‍💻+👨‍💻
# 105      PyData      Beginner   🇬🇧                  Matteo Barbieri      👨‍💻
# 107      PyLang      Beginner   🇬🇧  Lorenzo Buonanno,Tommaso Sartor  👨‍💻+👨‍💻
# 117      PyLang      Beginner   🇬🇧           Ludovico Orlando Russo      👨‍💻
# 154  PyBusiness      Beginner   🇬🇧                Francesco Porcari      👨‍💻
# 157      PyData      Beginner   🇮🇹                 Pietro Battiston      👨‍💻

# %% [markdown]
# <a name="talks"></a>
# # Talks Ranking (per single Track)

# %% [markdown]
# <a name="pycon"></a>
# ##  Track `PyLang`

# %%
pylang = talks[talks['Track'].values == 'PyLang']
pylang.index = np.arange(1, pylang.index.size+1)
pylang
# Out:
#     Type  Duration  \
# 1   Talk        45
# 2   Talk        45
# 3   Talk        30
# 4   Talk        45
# 5   Talk        60
# 6   Talk        45
# 7   Talk        45
# 8   Talk        60
# 9   Talk        30
# 10  Talk        45
# 11  Talk        45
# 12  Talk        60
# 13  Talk        45
# 14  Talk        60
# 15  Talk        60
# 16  Talk        45
# 17  Talk        45
# 18  Talk        45
# 19  Talk        45
# 20  Talk        30
# 21  Talk        45
# 22  Talk        30
# 23  Talk        45
# 24  Talk        45
# 25  Talk        30
# 26  Talk        60
# 27  Talk        45
# 28  Talk        45
# 29  Talk        45
# 30  Talk        45
# 31  Talk        45
# 32  Talk        45
# 33  Talk        60
# 34  Talk        30
# 35  Talk        45
# 36  Talk        45
#
#                                                                                      Title  \
# 1                                                                        Performant Python
# 2                                                                  Demystifying Decorators
# 3                                              Tales from the Crypt: A Cryptography Primer
# 4              ByteCode al supporto dei test per protocolli ed enforcing di best practices
# 5                   Solving the web most popular code shortening competition with Python 3
# 6                                                    Unreal Engine 4 e Python: Ora si Puo'
# 7                                                                  Python on $5 IoT Device
# 8                                                                       PyPy Status Update
# 9                                            Behavioral Driven Development: Tame the Beast
# 10                                                   Python e swift: linguaggi a confronto
# 11                                                  Test Driven Deployment with Ansible 2.
# 12                                                              42 PyCharm Tips and Tricks
# 13                                                  Chat Bot in Telegram (e slack e altri)
# 14                                              Creare videogiochi per smartphone con Kivy
# 15                                                                            Rusty Python
# 16                                                        Svilluppare con python sull'iPad
# 17                                                             Just one Shade of OpenStack
# 18                               Plugin Based Chat Bots in Telegram (and Slack and others)
# 19                                     Attack of Pythons : Gotchas and Landmines in Python
# 20                                       Loop better: a deeper look at iteration in Python
# 21                            Ansible roles, private git repos and the Ansible Galaxy tool
# 22                                                           Comprehensible Comprehensions
# 23                                                Rules of thumb to test the documentation
# 24                                      Continuous Delivery for Iot with Python and Iottly
# 25                                                     Python, Locales and Writing Systems
# 26                                               Cross-platform game development with Kivy
# 27             Ansible: sviluppo e utilizzo di roles seguendo il modello di Ansible Galaxy
# 28                                Artistic Python: Mixing Python Programming with Fashion
# 29                                                           Python + Windows, like a boss
# 30                          Pilotare un braccio robotico dal cloud con GenroPy e Raspberry
# 31                             Roboto Framework for Test Code Coverage for cloud services.
# 32                                                                             Awesome CLI
# 33  Creazione ed evoluzione di un framework per interfacce grafiche Multi-Touch con OpenGL
# 34                                                   James and the Giant Forensics Toolkit
# 35     ENVIFATE: plugin per QGIS per la valutazione del rischio di inquinamento ambientale
# 36                                            Terrain Generation in Python with Processing
#
#      Track         Level Lang                         Speakers   Gender
# 1   PyLang      Beginner   🇬🇧                   Burkhard Kloss      👨‍💻
# 2   PyLang      Beginner   🇬🇧                       Akul Mehra      👨‍💻
# 3   PyLang      Beginner   🇬🇧                   Adam Englander      👨‍💻
# 4   PyLang  Intermediate   🇮🇹                Alessandro Molina      👨‍💻
# 5   PyLang  Intermediate   🇬🇧                 Alessandro Amici      👨‍💻
# 6   PyLang      Beginner   🇮🇹                 Roberto De Ioris      👨‍💻
# 7   PyLang      Beginner   🇬🇧                        Ken Alger      👨‍💻
# 8   PyLang  Intermediate   🇬🇧                     Antonio Cuni      👨‍💻
# 9   PyLang      Beginner   🇬🇧                   Adam Englander      👨‍💻
# 10  PyLang  Intermediate   🇮🇹                  Lelio Campanile      👨‍💻
# 11  PyLang  Intermediate   🇬🇧                    Roberto Polli      👨‍💻
# 12  PyLang      Beginner   🇬🇧                  Dmitry Trofimov      👨‍💻
# 13  PyLang      Beginner   🇮🇹  Lorenzo Buonanno,Tommaso Sartor  👨‍💻+👨‍💻
# 14  PyLang  Intermediate   🇮🇹                   Rigel Di Scala      👨‍💻
# 15  PyLang  Intermediate   🇮🇹                   Matteo Bertini      👨‍💻
# 16  PyLang      Beginner   🇮🇹                  Lelio Campanile      👨‍💻
# 17  PyLang      Beginner   🇬🇧                    Roberto Polli      👨‍💻
# 18  PyLang      Beginner   🇬🇧  Lorenzo Buonanno,Tommaso Sartor  👨‍💻+👨‍💻
# 19  PyLang      Beginner   🇬🇧                     Manoj Pandey      👨‍💻
# 20  PyLang  Intermediate   🇬🇧                      Trey Hunner      👨‍💻
# 21  PyLang  Intermediate   🇬🇧                 serena lorenzini      👩‍💻
# 22  PyLang      Beginner   🇬🇧                      Trey Hunner      👨‍💻
# 23  PyLang  Intermediate   🇮🇹                      Marco Buttu      👨‍💻
# 24  PyLang  Intermediate   🇬🇧                    Stefano Terna      👨‍💻
# 25  PyLang  Intermediate   🇬🇧                      Rae Knowler      👩‍💻
# 26  PyLang  Intermediate   🇮🇹                   Rigel Di Scala      👨‍💻
# 27  PyLang  Intermediate   🇮🇹                 serena lorenzini      👩‍💻
# 28  PyLang      Beginner   🇬🇧                     Ria Baldevia      👩‍💻
# 29  PyLang  Intermediate   🇬🇧                   Nicola Iarocci      👨‍💻
# 30  PyLang      Beginner   🇮🇹                 Michele Bertoldi      👨‍💻
# 31  PyLang      Beginner   🇬🇧                   khushbu parakh      👩‍💻
# 32  PyLang      Beginner   🇬🇧                        Mark Fink      👨‍💻
# 33  PyLang      Advanced   🇮🇹                  Tiziano Carotti      👨‍💻
# 34  PyLang      Beginner   🇬🇧                 Tiberius Hefflin      👨‍💻
# 35  PyLang      Beginner   🇮🇹                   Francesco Geri      👨‍💻
# 36  PyLang  Intermediate   🇮🇹                    Paolo Improta      👨‍💻

# %%
print('Number of Talks Proposed: ', pylang.index.size, end='\n\n')

print('Language of Talks Proposed: ')
print(pylang.Lang.value_counts(), end='\n\n')

print('Levels of Talks Proposed: ')
print(pylang.Level.value_counts())
# Out:
# Number of Talks Proposed:  36
#
# Language of Talks Proposed:
# 🇬🇧    22
# 🇮🇹    14
# Name: Lang, dtype: int64
#
# Levels of Talks Proposed:
# Beginner        19
# Intermediate    16
# Advanced         1
# Name: Level, dtype: int64

# %% [markdown]
# <a name="pycomm"></a>
# ## Track `PyCommunity`

# %%
pycommunity = talks[talks['Track'].values == 'PyCommunity']
pycommunity.index = np.arange(1, pycommunity.index.size+1)
pycommunity
# Out:
#     Type  Duration  \
# 1   Talk        90
# 2   Talk        45
# 3   Talk        45
# 4   Talk        60
# 5   Talk        30
# 6   Talk        60
# 7   Talk        30
# 8   Talk        30
# 9   Talk        45
# 10  Talk        60
# 11  Talk        30
# 12  Talk        30
# 13  Talk        30
# 14  Talk        30
# 15  Talk        45
# 16  Talk        45
# 17  Talk        30
# 18  Talk        30
# 19  Talk        60
# 20  Talk        30
# 21  Talk        30
# 22  Talk        30
# 23  Talk        45
# 24  Talk        45
# 25  Talk        45
# 26  Talk        30
# 27  Talk        30
# 28  Talk        30
# 29  Talk        30
# 30  Talk        30
# 31  Talk        30
# 32  Talk        30
#
#                                                                                             Title  \
# 1                                                        L’Italia, python e la chimera dell’Agile
# 2                 Is it too late to learn how to program and how being a developer change my life
# 3                                                                        Perché Python fa schifo!
# 4                                                                                Python in Africa
# 5                                     From Idea to Presentation: How to Prepare a Conference Talk
# 6                                                                              E.T. chiama Python
# 7                                                        Be(come) a Mentor! Help Others Succeed!
# 8                      No Coding Skills Required: How to Contribute to Open Source in Other Ways
# 9                                                                      Growing a Python community
# 10                                                              Don't try to look smart. Be smart
# 11                                                                     Compassionate Code Reviews
# 12         Rants and Ruminations From A Job Applicant After 💯 CS Job Interviews in Silicon Valley
# 13                                                       The Hidden Power Dynamics of Open Source
# 14                  Applying the unix philosophy to django projects: a report from the real world
# 15                              Taiga e l’agile project management: join the Oompa Loompas’ Army!
# 16                                 Scientific Hooliganism: lessons from the first hack in history
# 17  Threading Yarn, Writing Code: What Traditional Arts and Crafts Can Teach Us About Programming
# 18                                                                    Navigating unconscious bias
# 19                                                                              E.T. phone Python
# 20                                                   Leading an open source project as a startup.
# 21                                                   Security Starts With You: Social Engineering
# 22                                                                            How Not To Password
# 23                                          ZimboPy: Empowering Zimbabwean Girls As Change Makers
# 24                            Keeping up with the pace of a fast growing community without dying
# 25                                                                    Combating Impostor Syndrome
# 26                                                                   Never Accept the First Offer
# 27                                                                           Mastering Your Tools
# 28                                                                   Why the Internet Loves Cats
# 29                                                                          Time Tracking is Hard
# 30                                                                     The Monster on the Project
# 31                                                                              Dial M For Mentor
# 32                                          People Are Coming To My Beginning Workshop, What Now?
#
#           Track         Level Lang              Speakers Gender
# 1   PyCommunity  Intermediate   🇮🇹     Gabriele Giaccari    👨‍💻
# 2   PyCommunity      Beginner   🇬🇧           Alicia Carr    👩‍💻
# 3   PyCommunity      Beginner   🇮🇹       Antonio Spadaro    👨‍💻
# 4   PyCommunity      Beginner   🇬🇧        Anna Makarudze    👩‍💻
# 5   PyCommunity      Beginner   🇬🇧         Anna Ossowski    👩‍💻
# 6   PyCommunity  Intermediate   🇮🇹          Davide Corio    👨‍💻
# 7   PyCommunity      Beginner   🇬🇧         Anna Ossowski    👩‍💻
# 8   PyCommunity      Beginner   🇬🇧         Anna Ossowski    👩‍💻
# 9   PyCommunity      Beginner   🇬🇧         Anton Caceres    👨‍💻
# 10  PyCommunity      Beginner   🇬🇧        Flavio Percoco    👨‍💻
# 11  PyCommunity      Beginner   🇬🇧          April Wensel    👩‍💻
# 12  PyCommunity      Beginner   🇬🇧             Susan Tan    👩‍💻
# 13  PyCommunity      Beginner   🇬🇧         Anna Ossowski    👩‍💻
# 14  PyCommunity      Beginner   🇬🇧      Federico Capoano    👨‍💻
# 15  PyCommunity  Intermediate   🇮🇹     Gabriele Giaccari    👨‍💻
# 16  PyCommunity      Beginner   🇬🇧            Lilly Ryan    👩‍💻
# 17  PyCommunity      Beginner   🇬🇧         Anna Ossowski    👩‍💻
# 18  PyCommunity      Beginner   🇬🇧        Anna Schneider    👩‍💻
# 19  PyCommunity  Intermediate   🇬🇧          Davide Corio    👨‍💻
# 20  PyCommunity      Beginner   🇬🇧       Nicolas Garnier    👨‍💻
# 21  PyCommunity      Beginner   🇬🇧      Tiberius Hefflin    👨‍💻
# 22  PyCommunity      Beginner   🇬🇧      Tiberius Hefflin    👨‍💻
# 23  PyCommunity      Beginner   🇬🇧      Marlene Mhangami    👩‍💻
# 24  PyCommunity      Beginner   🇬🇧        Flavio Percoco    👨‍💻
# 25  PyCommunity      Beginner   🇬🇧             Ken Alger    👨‍💻
# 26  PyCommunity      Beginner   🇬🇧      Tiberius Hefflin    👨‍💻
# 27  PyCommunity      Beginner   🇬🇧  Miguel Branco Palhas    👨‍💻
# 28  PyCommunity      Beginner   🇬🇧      Tiberius Hefflin    👨‍💻
# 29  PyCommunity  Intermediate   🇬🇧              Sam Deng    👨‍💻
# 30  PyCommunity      Beginner   🇬🇧      Tiberius Hefflin    👨‍💻
# 31  PyCommunity      Beginner   🇬🇧       Mariatta Wijaya    👩‍💻
# 32  PyCommunity      Beginner   🇬🇧        Nicholle James    👩‍💻

# %%
print('Number of Talks Proposed: ', pycommunity.index.size, end='\n\n')

print('Language of Talks Proposed: ')
print(pycommunity.Lang.value_counts(), end='\n\n')

print('Levels of Talks Proposed: ')
print(pycommunity.Level.value_counts())
# Out:
# Number of Talks Proposed:  32
#
# Language of Talks Proposed:
# 🇬🇧    28
# 🇮🇹     4
# Name: Lang, dtype: int64
#
# Levels of Talks Proposed:
# Beginner        27
# Intermediate     5
# Name: Level, dtype: int64

# %% [markdown]
# <div style="background-color: #FAFAFA">
#     <a name="pydata"></a>
#     <img src='logos/pydata.png' style="align: center;" width="50%" />
# </div>

# %%
pydataers = talks[talks['Track'].values == 'PyData']
pydataers.index = np.arange(1, pydataers.index.size+1)
pydataers
# Out:
#     Type  Duration  \
# 1   Talk        45
# 2   Talk        45
# 3   Talk        45
# 4   Talk        60
# 5   Talk        60
# 6   Talk        60
# 7   Talk        45
# 8   Talk        60
# 9   Talk        45
# 10  Talk        45
# 11  Talk        60
# 12  Talk        45
# 13  Talk        45
# 14  Talk        60
# 15  Talk        60
# 16  Talk        45
# 17  Talk        45
# 18  Talk        45
# 19  Talk        45
# 20  Talk        45
# 21  Talk        60
# 22  Talk        45
# 23  Talk        45
# 24  Talk        45
# 25  Talk        45
# 26  Talk        45
# 27  Talk        45
# 28  Talk        60
# 29  Talk        60
# 30  Talk        45
# 31  Talk        45
# 32  Talk        45
# 33  Talk        45
# 34  Talk        45
# 35  Talk        45
# 36  Talk        45
# 37  Talk        45
# 38  Talk        45
# 39  Talk        45
# 40  Talk        45
#
#                                                                                                    Title  \
# 1                                                     AI, Machine Learning e Deep Learning: cosa cambia?
# 2                                                Facial Analysis Techniques for Pythonista (and beyond!)
# 3                                                                    Solving the Rubiks Cube with Python
# 4                                                                                Deep Learning made easy
# 5                                                       The unconventional Introduction to Deep Learning
# 6                                                 A Gentle Introduction to Neural Networks (with Python)
# 7                                                              Introduction to Data-Analysis with Pandas
# 8              Machine Learning con Python: previsione in real-time della richiesta di energia elettrica
# 9                                               Affrontare le sfide del cambiamento climatico con Python
# 10                                                                      Time Series Analysis with Pandas
# 11                                    Machine Learning con Python: algoritmi NILM e real-time processing
# 12                                                                             OpenCV for face detection
# 13                                                                How to turn Wikipedia into a Quiz Game
# 14                        Where are you going? An overview on machine learning models for human mobility
# 15                      Tensor decomposition with Python: Learning structures from multidimensional data
# 16                                                 An Introduction to Pandas for Data Analysis in Python
# 17                                                     Basic principles of scientific data visualization
# 18                                                                        Explore the brain with Nilearn
# 19                                 An Introduction to Feature Selection in Machine Learning using Python
# 20  Word Embedding: come codificare il linguaggio naturale per algoritmi di previsione e classificazione
# 21                                          The Journey Of aeneas: A Python Adventure In Text and Speech
# 22                                                   Jupyter: if you don't use it yet you're doing wrong
# 23                                                                        Sparking Pandas: an experiment
# 24            Space weather monitoring for a simulation of a Martian settlement based on Virtual Reality
# 25                                                             Catching Neutrinos with Python and KM3NeT
# 26                                     Il Viaggio di aeneas: Un'Avventura Con Python Tra Testo e Parlato
# 27                                             Word Embeddings for Natural Language Processing in Python
# 28                                                       Validazione e decodifica di file XML con Python
# 29                                             Dai dati alla visualizzazione: la mia prima data pipeline
# 30                                                                       How to use pandas the wrong way
# 31        Misura: Un sistema per il controllo strumentale, l'acquisizione dati ed il calcolo scientifico
# 32                                                                       The Wild West of Data Wrangling
# 33                                                                                Come usare male pandas
# 34                                                               Monitoring Beach Morphology with Python
# 35                             Differential network analysis and graph classification: a glocal approach
# 36                 RFLab - Controllo remoto strumentazione di un laboratorio nel settore delle microonde
# 37                                                         Fuzzy is the new sexy: a tour of scikit-fuzzy
# 38                               Real-time Trajectory Optimization through contacts, a simple test case.
# 39        LiFT - Un tagger di features per l’analisi multidimensionale di testi ottimizzato per PySpark
# 40                                                                  ADENINE: A Data ExploratioN pIpeliNE
#
#      Track         Level Lang                        Speakers   Gender
# 1   PyData      Beginner   🇮🇹                 Antonio Spadaro      👨‍💻
# 2   PyData  Intermediate   🇬🇧                  Alex Casalboni      👨‍💻
# 3   PyData  Intermediate   🇬🇧                 Daan van Berkel      👨‍💻
# 4   PyData      Beginner   🇬🇧                 Jalem Raj Rohit      👨‍💻
# 5   PyData      Beginner   🇬🇧                  Valerio Maggio      👨‍💻
# 6   PyData      Beginner   🇬🇧                    Tariq Rashid      👨‍💻
# 7   PyData      Beginner   🇬🇧               Alexander Hendorf      👨‍💻
# 8   PyData      Beginner   🇮🇹                   Felice Tuosto      👨‍💻
# 9   PyData      Beginner   🇮🇹                Alessandro Amici      👨‍💻
# 10  PyData  Intermediate   🇬🇧               Alexander Hendorf      👨‍💻
# 11  PyData      Beginner   🇮🇹                   Felice Tuosto      👨‍💻
# 12  PyData      Beginner   🇬🇧                       Ken Alger      👨‍💻
# 13  PyData      Beginner   🇬🇧  Andrea Cappelli,Roberto Turrin  👨‍💻+👨‍💻
# 14  PyData      Beginner   🇮🇹                Gianni Barlacchi      👨‍💻
# 15  PyData  Intermediate   🇮🇹                  André Panisson      👨‍💻
# 16  PyData      Beginner   🇬🇧               Ayush Kumar Singh      👨‍💻
# 17  PyData      Beginner   🇬🇧                 Giuseppe Jurman      👨‍💻
# 18  PyData  Intermediate   🇬🇧                   Darya Chyzhyk      👩‍💻
# 19  PyData      Beginner   🇬🇧                   Rahul Baboota      👨‍💻
# 20  PyData      Beginner   🇮🇹      Felice Tuosto,Andrea Ianni  👨‍💻+👨‍💻
# 21  PyData  Intermediate   🇬🇧                Alberto Pettarin      👨‍💻
# 22  PyData      Beginner   🇬🇧                 Christian Barra      👨‍💻
# 23  PyData  Intermediate   🇬🇧                 Francesco Bruni      👨‍💻
# 24  PyData      Beginner   🇬🇧                  Giovanni Bruno      👨‍💻
# 25  PyData      Beginner   🇬🇧                       Tamás Gál      👨‍💻
# 26  PyData      Beginner   🇮🇹                Alberto Pettarin      👨‍💻
# 27  PyData      Beginner   🇬🇧                 Marco Bonzanini      👨‍💻
# 28  PyData  Intermediate   🇮🇹                  Davide Brunato      👨‍💻
# 29  PyData      Beginner   🇮🇹          Riccardo Magliocchetti      👨‍💻
# 30  PyData  Intermediate   🇬🇧                Pietro Battiston      👨‍💻
# 31  PyData      Beginner   🇮🇹               Daniele Paganelli      👨‍💻
# 32  PyData  Intermediate   🇬🇧                     Sarah Guido      👩‍💻
# 33  PyData  Intermediate   🇮🇹                Pietro Battiston      👨‍💻
# 34  PyData      Beginner   🇮🇹                    Luca Liberti      👨‍💻
# 35  PyData  Intermediate   🇬🇧                 Giuseppe Jurman      👨‍💻
# 36  PyData  Intermediate   🇮🇹                     Andrea Saba      👨‍💻
# 37  PyData      Beginner   🇮🇹                   Niccolo Raspa      👨‍💻
# 38  PyData  Intermediate   🇮🇹                  Tommaso Sartor      👨‍💻
# 39  PyData      Beginner   🇮🇹                  Michele Gabusi      👨‍💻
# 40  PyData      Beginner   🇬🇧                 Samuele Fiorini      👨‍💻

# %%
print('Number of Talks Proposed: ', pydataers.index.size, end='\n\n')

print('Language of Talks Proposed: ')
print(pydataers.Lang.value_counts(), end='\n\n')

print('Levels of Talks Proposed: ')
print(pydataers.Level.value_counts())
# Out:
# Number of Talks Proposed:  40
#
# Language of Talks Proposed:
# 🇬🇧    23
# 🇮🇹    17
# Name: Lang, dtype: int64
#
# Levels of Talks Proposed:
# Beginner        26
# Intermediate    14
# Name: Level, dtype: int64

# %% [markdown]
# <a name="pyweb"></a>
# ## Track `PyWeb`

# %%
pyweb = talks[talks['Track'].values == 'PyWeb']
pyweb.index = np.arange(1, pyweb.index.size+1)
pyweb
# Out:
#     Type  Duration  \
# 1   Talk        45
# 2   Talk        45
# 3   Talk        45
# 4   Talk        45
# 5   Talk        30
# 6   Talk        45
# 7   Talk        60
# 8   Talk        45
# 9   Talk        60
# 10  Talk        45
# 11  Talk        60
# 12  Talk        45
# 13  Talk        30
# 14  Talk        45
# 15  Talk        45
# 16  Talk        30
# 17  Talk        30
# 18  Talk        60
# 19  Talk        45
# 20  Talk        60
# 21  Talk        45
# 22  Talk        45
# 23  Talk        30
# 24  Talk        30
# 25  Talk        60
# 26  Talk        45
# 27  Talk        45
# 28  Talk        30
# 29  Talk        60
# 30  Talk        30
# 31  Talk        60
# 32  Talk        45
# 33  Talk        30
# 34  Talk        45
# 35  Talk        30
# 36  Talk        30
# 37  Talk        60
# 38  Talk        30
# 39  Talk        30
# 40  Talk        30
# 41  Talk        30
# 42  Talk        30
# 43  Talk        60
# 44  Talk        30
# 45  Talk        30
# 46  Talk        30
#
#                                                                                          Title  \
# 1                                                 Building Serverless applications with Python
# 2                   Create a serverless infrastructure for data collection with Python and AWS
# 3                        Indicizzare e ricercare tonnellate di dati con ElasticSearch e Django
# 4                                                          Django Rest Framework - Tips&Tricks
# 5                   Out of Sight, Out of Mind: Survival tricks and tools for remote developers
# 6                                                                     Crash test of Django ORM
# 7                                                        Understanding Serverless Architecture
# 8                                                   Getting started with requests HTTP library
# 9                                                        Serverless computing con Python e AWS
# 10                             Deploy automatizzato di un progetto Python 3/Django con Ansible
# 11                                                    Serverless computing with Python and AWS
# 12                                      Why I still develop synchronous web in the asyncIO era
# 13                            Django among modern web frameworks – was Angular2 a good choice?
# 14                                                An Introduction to web scraping using Python
# 15                                   Perché sviluppo ancora web sincrono nell'era dell'asyncIO
# 16                                                              Django and the testing pyramid
# 17                                             Data loss prevention in modern web applications
# 18                                           Amazon Web Services for dummies - tips and tricks
# 19                                              OpneSSH SFTP service con Python: pysftpserver.
# 20                                 Amazon Web Services per i principianti - consigli e trucchi
# 21                                       Open edX, soluzione per l'e-learning basata su Django
# 22                                  Automated deploy of a Python 3/Django project with Ansible
# 23                                                      Type uWSGI; press enter; what happens?
# 24                                                 Planet friendly web development with Django
# 25                                                           weppy: il framework web per umani
# 26                                  Presenting pysftpserver: OpenSSH SFTP service with Python.
# 27                                                            Django nella giungla Javascript
# 28                                                  The hard long journey of submitting a form
# 29                                                       Infrastructure as Code with Terraform
# 30                  The mullet architecture - Elasticsearch in the front, Postgres in the back
# 31                                                    Infrastruttura come codice con Terraform
# 32                                 Geospatial three amigos: Python, Leaflet, and ElasticSearch
# 33                                                         Django Admin - The Swiss Army Knife
# 34            MIT MicroMasters: come sviluppare una web application basata su servizi esterni.
# 35                    Serverlessness - augmenting your Django apps with Functions-as-a-Service
# 36                                                     Qualities of great reusable Django apps
# 37                                                         weppy: the web framework for humans
# 38                                                              Scaling Django with Kubernetes
# 39                                Beginning with django? Why you need to continue with django
# 40  Migrating from JavaEE to Django: the OSIS case of embracing cultural and technical changes
# 41                                                   Integrating the Bokeh library with Django
# 42                                          Preventing issues on Django with linters and tools
# 43                                 Django ORM in server TCP con backend multischema PostgreSQL
# 44                                              Deploying your django application using puppet
# 45                      Addons: I can solve 90% of your problems. The other 90% are up to you.
# 46                                                                        Using SASS in Django
#
#     Track         Level Lang                        Speakers Gender
# 1   PyWeb      Advanced   🇬🇧               Andrii Soldatenko    👨‍💻
# 2   PyWeb  Intermediate   🇮🇹                  David Santucci    👨‍💻
# 3   PyWeb  Intermediate   🇮🇹                Ernesto Arbitrio    👨‍💻
# 4   PyWeb      Beginner   🇮🇹                  Luca Zacchetti    👨‍💻
# 5   PyWeb      Beginner   🇬🇧               Alessio Bragadini    👨‍💻
# 6   PyWeb  Intermediate   🇬🇧               Andrii Soldatenko    👨‍💻
# 7   PyWeb      Beginner   🇬🇧                 Jalem Raj Rohit    👨‍💻
# 8   PyWeb      Beginner   🇮🇹                   Andrea Grandi    👨‍💻
# 9   PyWeb  Intermediate   🇮🇹                 Federico Caboni    👨‍💻
# 10  PyWeb  Intermediate   🇮🇹                Marco Santamaria    👨‍💻
# 11  PyWeb  Intermediate   🇬🇧                 Federico Caboni    👨‍💻
# 12  PyWeb  Intermediate   🇬🇧              Giovanni Barillari    👨‍💻
# 13  PyWeb  Intermediate   🇬🇧                Andrzej Krawczyk    👨‍💻
# 14  PyWeb      Beginner   🇬🇧                    Manoj Pandey    👨‍💻
# 15  PyWeb  Intermediate   🇮🇹              Giovanni Barillari    👨‍💻
# 16  PyWeb  Intermediate   🇬🇧                   Aaron Bassett    👨‍💻
# 17  PyWeb      Beginner   🇬🇧                 Xavier Dutreilh    👨‍💻
# 18  PyWeb      Beginner   🇬🇧              Justyna Janczyszyn    👩‍💻
# 19  PyWeb  Intermediate   🇮🇹                 Filippo Morelli    👨‍💻
# 20  PyWeb      Beginner   🇮🇹              Justyna Janczyszyn    👩‍💻
# 21  PyWeb      Beginner   🇮🇹                    Davide Corio    👨‍💻
# 22  PyWeb  Intermediate   🇬🇧                Marco Santamaria    👨‍💻
# 23  PyWeb      Advanced   🇬🇧                    Philip James    👨‍💻
# 24  PyWeb  Intermediate   🇬🇧                     Chris Adams    👨‍💻
# 25  PyWeb      Beginner   🇮🇹              Giovanni Barillari    👨‍💻
# 26  PyWeb  Intermediate   🇬🇧                 Filippo Morelli    👨‍💻
# 27  PyWeb      Beginner   🇮🇹           Patrick Guido Arminio    👨‍💻
# 28  PyWeb  Intermediate   🇬🇧       Filipe de Alencar Ximenes    👨‍💻
# 29  PyWeb      Beginner   🇬🇧              Justyna Janczyszyn    👩‍💻
# 30  PyWeb  Intermediate   🇬🇧                      Honza Král    👨‍💻
# 31  PyWeb      Beginner   🇮🇹              Justyna Janczyszyn    👩‍💻
# 32  PyWeb      Beginner   🇬🇧                 Roberto Rosario    👨‍💻
# 33  PyWeb  Intermediate   🇬🇧                   Prakash Kumar    👨‍💻
# 34  PyWeb      Beginner   🇮🇹               Giovanni Di Milia    👨‍💻
# 35  PyWeb  Intermediate   🇬🇧                       Tom Dyson    👨‍💻
# 36  PyWeb  Intermediate   🇬🇧  Flávio Juvenal da Silva Junior    👨‍💻
# 37  PyWeb      Beginner   🇬🇧              Giovanni Barillari    👨‍💻
# 38  PyWeb  Intermediate   🇬🇧                   Saket Bhushan    👨‍💻
# 39  PyWeb      Beginner   🇬🇧                Opetunde Adepoju    👩‍💻
# 40  PyWeb      Beginner   🇬🇧             Hildeberto Mendonca    👨‍💻
# 41  PyWeb      Beginner   🇬🇧                       Ken Alger    👨‍💻
# 42  PyWeb      Beginner   🇬🇧  Flávio Juvenal da Silva Junior    👨‍💻
# 43  PyWeb  Intermediate   🇮🇹                    Luca Ferroni    👨‍💻
# 44  PyWeb      Beginner   🇬🇧                 Krzysztof Żuraw    👨‍💻
# 45  PyWeb  Intermediate   🇬🇧                   Stefan Foulis    👨‍💻
# 46  PyWeb      Beginner   🇬🇧                      Jacob Rief    👨‍💻

# %%
print('Number of Talks Proposed: ', pyweb.index.size, end='\n\n')

print('Language of Talks Proposed: ')
print(pyweb.Lang.value_counts(), end='\n\n')

print('Levels of Talks Proposed: ')
print(pyweb.Level.value_counts())
# Out:
# Number of Talks Proposed:  46
#
# Language of Talks Proposed:
# 🇬🇧    31
# 🇮🇹    15
# Name: Lang, dtype: int64
#
# Levels of Talks Proposed:
# Beginner        22
# Intermediate    22
# Advanced         2
# Name: Level, dtype: int64

# %% [markdown]
# <a name="pybusiness"></a>
# ##  Track `PyBusiness`

# %%
pybusiness = talks[talks['Track'].values == 'PyBusiness']
pybusiness.index = np.arange(1, pybusiness.index.size+1)
pybusiness
# Out:
#     Type  Duration  \
# 1   Talk        60
# 2   Talk        45
# 3   Talk        45
# 4   Talk        45
# 5   Talk        45
# 6   Talk        45
# 7   Talk        60
# 8   Talk        45
# 9   Talk        45
# 10  Talk        45
# 11  Talk        45
#
#                                                                                               Title  \
# 1                                                   Realizzare stampe HTML e PDF usando solo Python
# 2                                                                      Da applicativi Desktop a Web
# 3                                                                 Analisi dati e grafici in Genropy
# 4                                                    iCond: GenroPy per amministratori di condomini
# 5                                                                     Sviluppo lato client con Odoo
# 6                                                                  Form e Campi dinamici in Genropy
# 7                                             Genropy: 10 anni di sviluppo di un framework italiano
# 8   Genropy - Caso d'uso: gestione di una infrastruttura telefonica VoIP di medie/grandi dimensioni
# 9                                                                                Un anno di Genropy
# 10                                                Wargame web app - Odoo come framework di sviluppo
# 11                                                               Usare Erpy da applicazioni esterne
#
#          Track         Level Lang                  Speakers Gender
# 1   PyBusiness      Beginner   🇮🇹           Saverio Porcari    👨‍💻
# 2   PyBusiness      Beginner   🇮🇹               Luigi Renna    👨‍💻
# 3   PyBusiness      Beginner   🇮🇹         Francesco Porcari    👨‍💻
# 4   PyBusiness      Beginner   🇮🇹          Andrea Busanelli    👨‍💻
# 5   PyBusiness      Advanced   🇮🇹              Davide Corio    👨‍💻
# 6   PyBusiness      Beginner   🇮🇹         Francesco Porcari    👨‍💻
# 7   PyBusiness      Beginner   🇮🇹          Giovanni Porcari    👨‍💻
# 8   PyBusiness      Beginner   🇮🇹             Mauro Zanardi    👨‍💻
# 9   PyBusiness      Beginner   🇮🇹  Muhammad Hassan Khurshid    👨‍💻
# 10  PyBusiness  Intermediate   🇮🇹        Nicola Malcontenti    👨‍💻
# 11  PyBusiness      Beginner   🇮🇹          Giovanni Porcari    👨‍💻

# %%
print('Number of Talks Proposed: ', pybusiness.index.size, end='\n\n')

print('Language of Talks Proposed: ')
print(pybusiness.Lang.value_counts(), end='\n\n')

print('Levels of Talks Proposed: ')
print(pybusiness.Level.value_counts())
# Out:
# Number of Talks Proposed:  11
#
# Language of Talks Proposed:
# 🇮🇹    11
# Name: Lang, dtype: int64
#
# Levels of Talks Proposed:
# Beginner        9
# Advanced        1
# Intermediate    1
# Name: Level, dtype: int64

# %% [markdown]
# <a name="pydb"></a>
# ## Track `PyDatabase`

# %%
pydb = talks[talks['Track'].values == 'PyDatabase']
pydb.index = np.arange(1, pydb.index.size+1)
pydb
# Out:
#    Type  Duration  \
# 1  Talk        60
# 2  Talk        45
# 3  Talk        45
# 4  Talk        60
# 5  Talk        45
# 6  Talk        45
# 7  Talk        45
#
#                                                                                                Title  \
# 1  Digital Analytics Data Aggregation: un case study dal mondo reale utilizzando SQL, NoSQL e Pandas
# 2                                                                    Full Text Search con PostgreSQL
# 3                                                  Disaster recovery: una serie di sfortunati eventi
# 4                                                          Python e PostgreSQL, un connubio perfetto
# 5                                                         Ricerca full text in Django con PostgreSQL
# 6                                                                   PostgreSQL su NFS: miti e verità
# 7                                                             Taking care of PostgreSQL with Ansible
#
#         Track         Level Lang               Speakers Gender
# 1  PyDatabase      Advanced   🇮🇹  Alessandro Pelliciari    👨‍💻
# 2  PyDatabase      Beginner   🇮🇹      Giuseppe Broccolo    👨‍💻
# 3  PyDatabase      Beginner   🇮🇹        Giulio Calacoci    👨‍💻
# 4  PyDatabase      Beginner   🇮🇹       Marco Nenciarini    👨‍💻
# 5  PyDatabase  Intermediate   🇮🇹       Paolo Melchiorre    👨‍💻
# 6  PyDatabase  Intermediate   🇮🇹      Jonathan Battiato    👨‍💻
# 7  PyDatabase      Beginner   🇬🇧           Rubens Souza    👨‍💻

# %%
print('Number of Talks Proposed: ', pydb.index.size, end='\n\n')

print('Language of Talks Proposed: ')
print(pydb.Lang.value_counts(), end='\n\n')

print('Levels of Talks Proposed: ')
print(pydb.Level.value_counts())
# Out:
# Number of Talks Proposed:  7
#
# Language of Talks Proposed:
# 🇮🇹    6
# 🇬🇧    1
# Name: Lang, dtype: int64
#
# Levels of Talks Proposed:
# Beginner        4
# Intermediate    2
# Advanced        1
# Name: Level, dtype: int64
